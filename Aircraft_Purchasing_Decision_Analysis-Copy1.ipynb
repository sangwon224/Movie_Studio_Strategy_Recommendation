# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 


pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("data/Aviation_Data.csv", low_memory=False)

# %%
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2    Saltville, VA  United States  36.922223  -81.878056          NaN
# 3       EUREKA, CA  United States        NaN         NaN          NaN
# 4       Canton, OH  United States        NaN         NaN          NaN
#
#   Airport.Name Injury.Severity Aircraft.damage Aircraft.Category  \
# 0          NaN        Fatal(2)       Destroyed               NaN
# 1          NaN        Fatal(4)       Destroyed               NaN
# 2          NaN        Fatal(3)       Destroyed               NaN
# 3          NaN        Fatal(2)       Destroyed               NaN
# 4          NaN        Fatal(1)       Destroyed               NaN
#
#   Registration.Number      Make     Model Amateur.Built  Number.of.Engines  \
# 0              NC6404   Stinson     108-3            No                1.0
# 1              N5069P     Piper  PA24-180            No                1.0
# 2              N5142R    Cessna      172M            No                1.0
# 3              N1168J  Rockwell       112            No                1.0
# 4               N15NY    Cessna       501            No                NaN
#
#      Engine.Type FAR.Description Schedule Purpose.of.flight Air.carrier  \
# 0  Reciprocating             NaN      NaN          Personal         NaN
# 1  Reciprocating             NaN      NaN          Personal         NaN
# 2  Reciprocating             NaN      NaN          Personal         NaN
# 3  Reciprocating             NaN      NaN          Personal         NaN
# 4            NaN             NaN      NaN          Personal         NaN
#
#    Total.Fatal.Injuries  Total.Serious.Injuries  Total.Minor.Injuries  \
# 0                   2.0                     0.0                   0.0
# 1                   4.0                     0.0                   0.0
# 2                   3.0                     NaN                   NaN
# 3                   2.0                     0.0                   0.0
# 4                   1.0                     2.0                   NaN
#
#    Total.Uninjured Weather.Condition Broad.phase.of.flight   Report.Status  \
# 0              0.0               UNK                Cruise  Probable Cause
# 1              0.0               UNK               Unknown  Probable Cause
# 2              NaN               IMC                Cruise  Probable Cause
# 3              0.0               IMC                Cruise  Probable Cause
# 4              0.0               VMC              Approach  Probable Cause
#
#   Publication.Date
# 0              NaN
# 1       19-09-1996
# 2       26-02-2007
# 3       12-09-2000
# 4       16-04-1980

# %%
print(df.duplicated().sum())
# Out:
# 1390

# %%
new_df = df.drop_duplicates(ignore_index=False)

# %%
print(new_df.duplicated().sum())
# Out:
# 0

# %%
new_df = new_df.loc[(new_df['Investigation.Type'] == 'Accident') 
                   & (new_df['Country'] == 'United States')
                    & (new_df['Event.Date'] > '2001-11-01')
                    & (new_df['Aircraft.Category'] == 'Airplane')
                    & ((new_df['Purpose.of.flight'] == 'Personal')
                    | (new_df['Purpose.of.flight'] == 'Business')
                       | (new_df['Purpose.of.flight'] == 'Other work use')
                       | (new_df['Purpose.of.flight'] == 'Public Aircraft')
                       | (new_df['Purpose.of.flight'] == 'Executive/corporate')
                       | (new_df['Purpose.of.flight'] == 'Public Aircraft - Federal')
                       | (new_df['Purpose.of.flight'] == 'Public Aircraft - Local')
                       | (new_df['Purpose.of.flight'] == 'Public Aircraft - State'))
                   ]

# %%
new_df = new_df.dropna(subset=['Make'])

# %%
new_df['Make'] = new_df['Make'].str.title()

# %%
new_df['Make'].value_counts()
# Out:
# Cessna             4211
# Piper              2641
# Beech               974
# Mooney              300
# Maule               193
#                    ...
# Lee                   1
# Meyer Fred J          1
# James H Berard        1
# Evans James Jay       1
# Spartan               1
# Name: Make, Length: 2919, dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14577 entries, 51768 to 90345
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                14577 non-null  object
#  1   Investigation.Type      14577 non-null  object
#  2   Accident.Number         14577 non-null  object
#  3   Event.Date              14577 non-null  object
#  4   Location                14577 non-null  object
#  5   Country                 14577 non-null  object
#  6   Latitude                14562 non-null  object
#  7   Longitude               14554 non-null  object
#  8   Airport.Code            10686 non-null  object
#  9   Airport.Name            10687 non-null  object
#  10  Injury.Severity         14572 non-null  object
#  11  Aircraft.damage         14545 non-null  object
#  12  Aircraft.Category       14577 non-null  object
#  13  Registration.Number     14577 non-null  object
#  14  Make                    14577 non-null  object
#  15  Model                   14576 non-null  object
#  16  Amateur.Built           14575 non-null  object
#  17  Number.of.Engines       14179 non-null  float64
#  18  Engine.Type             13295 non-null  object
#  19  FAR.Description         14577 non-null  object
#  20  Schedule                231 non-null    object
#  21  Purpose.of.flight       14577 non-null  object
#  22  Air.carrier             5377 non-null   object
#  23  Total.Fatal.Injuries    12607 non-null  float64
#  24  Total.Serious.Injuries  12655 non-null  float64
#  25  Total.Minor.Injuries    12934 non-null  float64
#  26  Total.Uninjured         14134 non-null  float64
#  27  Weather.Condition       14324 non-null  object
#  28  Broad.phase.of.flight   2103 non-null   object
#  29  Report.Status           13028 non-null  object
#  30  Publication.Date        13535 non-null  object
# dtypes: float64(5), object(26)
# memory usage: 3.6+ MB

# %%
new_df['Total.Fatal.Injuries'] = new_df['Total.Fatal.Injuries'].fillna(value=0)
new_df['Total.Serious.Injuries'] = new_df['Total.Serious.Injuries'].fillna(value=0)
new_df['Total.Minor.Injuries'] = new_df['Total.Minor.Injuries'].fillna(value=0)

# %%
new_df['Total.Injuries'] = new_df['Total.Fatal.Injuries'] + new_df['Total.Serious.Injuries'] + new_df['Total.Minor.Injuries']

# %%
new_df.head(30)
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 51768  20011119X02259           Accident      FTW02FA036  2001-11-12
# 51955  20020110X00057           Accident      IAD02FA024  2001-12-30
# 51987  20020114X00065           Accident      FTW02LA066  2002-01-10
# 52013  20020123X00101           Accident      FTW02LA067  2002-01-15
# 52361  20020415X00514           Accident      IAD02LA040  2002-04-03
# 52687  20020607X00829           Accident      FTW02LA168  2002-05-31
# 52708  20020604X00801           Accident      CHI02LA147  2002-06-02
# 52932  20020719X01174           Accident      CHI02CA196  2002-06-30
# 52974  20020716X01137           Accident      CHI02CA182  2002-07-04
# 53002  20020715X01130           Accident      CHI02CA184  2002-07-07
# 53036  20020717X01146           Accident      FTW02CA207  2002-07-13
# 53039  20020726X01235           Accident      CHI02CA198  2002-07-13
# 53040  20020716X01141           Accident      CHI02CA191  2002-07-13
# 53088  20020726X01233           Accident      CHI02CA203  2002-07-19
# 53089  20020731X01274           Accident      CHI02CA202  2002-07-19
# 53096  20020731X01275           Accident      CHI02CA214  2002-07-20
# 53185  20020802X01289           Accident      CHI02LA226  2002-08-01
# 53190  20020816X01414           Accident      NYC02FA152  2002-08-01
# 53204  20020815X01398           Accident      IAD02TA081  2002-08-03
# 53316  20020828X01475           Accident      CHI02CA253  2002-08-17
# 53408  20021023X05374           Accident      CHI02CA267  2002-08-31
# 53425  20020916X01608           Accident      NYC02FA178  2002-09-02
# 53453  20020925X05215           Accident      CHI02CA279  2002-09-06
# 53521  20021018X05339           Accident      CHI02CA287  2002-09-17
# 53534  20021023X05373           Accident      MIA02CA177  2002-09-21
# 53591  20021004X05280           Accident      NYC02FA200  2002-09-30
# 53612  20030919X01561           Accident      CHI03CA004  2002-10-05
# 53686  20021024X05379           Accident      ANC03CA004  2002-10-20
# 53713  20021030X05407           Accident      ANC03CA006  2002-10-25
# 53731  20021105X05434           Accident      ANC03CA008  2002-10-29
#
#                     Location        Country   Latitude    Longitude  \
# 51768             Graham, TX  United States  33.256667   -98.447222
# 51955            MILFORD, CT  United States  41.182223   -73.026945
# 51987        ALBUQUERQUE, NM  United States        NaN          NaN
# 52013              IRAAN, TX  United States  30.905556  -101.891944
# 52361        MOUNT HOLLY, NJ  United States  39.942777   -74.845555
# 52687             CONWAY, AR  United States  35.080556   -92.424723
# 52708           GOODLAND, KS  United States        NaN          NaN
# 52932       JACKSONVILLE, IL  United States  39.774723   -90.238333
# 52974             MONROE, MI  United States      41.94   -83.434722
# 53002             LOWELL, MI  United States  42.953889   -85.343889
# 53036          SPICEWOOD, TX  United States  30.501111   -98.146944
# 53039           SCRIBNER, NE  United States  41.610278       -96.63
# 53040            MECOSTA, MI  United States  43.629167     -85.2625
# 53088             JUNEAU, WI  United States  43.426667   -88.703333
# 53089           MATTAWAN, MI  United States  42.195833   -85.805556
# 53096            LARETTO, MN  United States  45.081111   -93.668334
# 53185            OZAWKIE, KS  United States      39.07   -95.626389
# 53190           Marietta, PA  United States  40.087777   -76.581945
# 53204  MARTHA'S VINEYARD, MA  United States  41.324445   -70.573889
# 53316             OHIAWA, NE  United States  40.301111   -96.803889
# 53408          CAMP LAKE, WI  United States  42.533333   -88.158333
# 53425            Swanzey, NH  United States  42.866667   -72.242222
# 53453         Brookfield, WI  United States    43.0875   -88.177778
# 53521       DODGE CENTER, MN  United States  44.018056   -92.831389
# 53534       CHERRY POINT, NC  United States    34.9025   -76.880834
# 53591         West Creek, NJ  United States  39.665278   -74.308056
# 53612               OSLO, MN  United States       48.2   -97.133333
# 53686            WASILLA, AK  United States  61.571389  -149.540555
# 53713          ANCHORAGE, AK  United States  61.186944  -149.965278
# 53731             Palmer, AK  United States  61.416667      -148.55
#
#       Airport.Code                    Airport.Name Injury.Severity  \
# 51768          E15                Graham Municipal        Fatal(4)
# 51955          BDR        Igor I. Sikorsky Airport        Fatal(1)
# 51987          AEG                 DOUBLE EAGLE II       Non-Fatal
# 52013          2F0         Iraan Municipal Airport       Non-Fatal
# 52361          VAY               SOUTH JERSEY RGNL       Non-Fatal
# 52687          M03           Dennis Cantrell Field       Non-Fatal
# 52708          GLD  RENNER FLD /GOODLAND MUNICIPAL       Non-Fatal
# 52932          IJX               Jacksonville Muni       Non-Fatal
# 52974          TTF                          CUSTER       Non-Fatal
# 53002          24C                     Lowell City       Non-Fatal
# 53036          NaN                             NaN       Non-Fatal
# 53039          SCB                  Scribner State       Non-Fatal
# 53040           MI                         Mecosta       Non-Fatal
# 53088          UNU                    DODGE COUNTY       Non-Fatal
# 53089         8MI3                 Mattawn Airpark       Non-Fatal
# 53096         MN66                       INGLESIDE       Non-Fatal
# 53185          NaN                             NaN       Non-Fatal
# 53190          N71                 Donegal Springs        Fatal(4)
# 53204          NaN                             NaN        Fatal(1)
# 53316          NaN                             NaN       Non-Fatal
# 53408          NaN                             NaN       Non-Fatal
# 53425          EEN         Dillant Hopkins Airport        Fatal(7)
# 53453          NaN                             NaN       Non-Fatal
# 53521          NaN                             NaN       Non-Fatal
# 53534          MKT    Cherry Point MCAS/Cunningham       Non-Fatal
# 53591          31E             Eagles Nest Airport        Fatal(1)
# 53612          NaN    Cenex Co. airstrip (private)       Non-Fatal
# 53686         PAWS                         WASILLA       Non-Fatal
# 53713          Z41                 Lake Hood Strip       Non-Fatal
# 53731          NaN                             NaN       Non-Fatal
#
#       Aircraft.damage Aircraft.Category Registration.Number  \
# 51768       Destroyed          Airplane              N6134A
# 51955     Substantial          Airplane              N7427J
# 51987     Substantial          Airplane               N87WW
# 52013     Substantial          Airplane               N509R
# 52361     Substantial          Airplane              N5079J
# 52687     Substantial          Airplane              N94769
# 52708     Substantial          Airplane              NC662Y
# 52932     Substantial          Airplane               N1419
# 52974     Substantial          Airplane              N3545R
# 53002     Substantial          Airplane               N52WP
# 53036     Substantial          Airplane              N358RW
# 53039     Substantial          Airplane              N290KB
# 53040     Substantial          Airplane              N6912S
# 53088     Substantial          Airplane                 N9B
# 53089     Substantial          Airplane              N747BS
# 53096     Substantial          Airplane              N6321B
# 53185     Substantial          Airplane              N1029G
# 53190       Destroyed          Airplane              N81310
# 53204     Substantial          Airplane                 N3R
# 53316     Substantial          Airplane              N8851V
# 53408     Substantial          Airplane              N369AF
# 53425       Destroyed          Airplane              N6688D
# 53453             NaN          Airplane              N2601N
# 53521     Substantial          Airplane              N2870S
# 53534     Substantial          Airplane                N6QR
# 53591       Destroyed          Airplane              N5556Q
# 53612     Substantial          Airplane              N3345Y
# 53686     Substantial          Airplane              N1302D
# 53713     Substantial          Airplane              N5244D
# 53731       Destroyed          Airplane               N878A
#
#                       Make             Model Amateur.Built  Number.of.Engines  \
# 51768                Piper           PA-31T1            No                2.0
# 51955                Piper        PA-28R-180            No                1.0
# 51987                Piper            PA-46T            No                1.0
# 52013               Cessna               172            No                1.0
# 52361               Cessna             T310R            No                2.0
# 52687              Ercoupe        ERCO-415-E            No                1.0
# 52708                 Waco               ASO            No                1.0
# 52932              Grenier        Acro Sport            No                1.0
# 52974                Beech           A-23-23            No                1.0
# 53002                Piper             PA-34            No                2.0
# 53036  Gulfstream American             AA-5B            No                1.0
# 53039             Baughman              KR-2           Yes                1.0
# 53040               Cessna              150H            No                1.0
# 53088               Bilgri    Sonerai II Lts           Yes                1.0
# 53089             Eckstein             RV-6A           Yes                1.0
# 53096               Cessna              182A            No                1.0
# 53185               Giroux           Air Cam           Yes                2.0
# 53190     Grumman American             AA-5B            No                1.0
# 53204             Crawford  Widebody Long EZ           Yes                1.0
# 53316             Bellanca         BL-17-30A            No                1.0
# 53408               Tomash        Avid Flyer           Yes                1.0
# 53425           Beechcraft               58P            No                2.0
# 53453               Cessna               120            No                1.0
# 53521               Cessna              150G            No                1.0
# 53534                Aviat               A-1            No                1.0
# 53591               Mooney              M20E            No                1.0
# 53612               Cessna              182E            No                1.0
# 53686               Cessna               180            No                1.0
# 53713               Cessna               180            No                1.0
# 53731                Piper             PA-22            No                1.0
#
#          Engine.Type            FAR.Description Schedule    Purpose.of.flight  \
# 51768     Turbo Prop  Part 91: General Aviation      NaN  Executive/corporate
# 51955  Reciprocating  Part 91: General Aviation      NaN             Personal
# 51987     Turbo Prop  Part 91: General Aviation      NaN             Personal
# 52013  Reciprocating  Part 91: General Aviation      NaN             Personal
# 52361  Reciprocating  Part 91: General Aviation      NaN             Personal
# 52687  Reciprocating  Part 91: General Aviation      NaN             Personal
# 52708  Reciprocating  Part 91: General Aviation      NaN             Personal
# 52932  Reciprocating  Part 91: General Aviation      NaN             Personal
# 52974  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53002  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53036  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53039  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53040  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53088  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53089  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53096  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53185  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53190  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53204  Reciprocating                 Public Use      NaN      Public Aircraft
# 53316  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53408  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53425  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53453  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53521  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53534  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53591  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53612  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53686  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53713  Reciprocating  Part 91: General Aviation      NaN             Personal
# 53731  Reciprocating  Part 91: General Aviation      NaN             Personal
#
#       Air.carrier  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 51768         NaN                   4.0                     0.0
# 51955         NaN                   1.0                     0.0
# 51987         NaN                   0.0                     0.0
# 52013         NaN                   0.0                     0.0
# 52361         NaN                   0.0                     1.0
# 52687         NaN                   0.0                     0.0
# 52708         NaN                   0.0                     0.0
# 52932         NaN                   0.0                     0.0
# 52974         NaN                   0.0                     0.0
# 53002         NaN                   0.0                     0.0
# 53036         NaN                   0.0                     0.0
# 53039         NaN                   0.0                     0.0
# 53040         NaN                   0.0                     0.0
# 53088         NaN                   0.0                     0.0
# 53089         NaN                   0.0                     0.0
# 53096         NaN                   0.0                     0.0
# 53185         NaN                   0.0                     0.0
# 53190         NaN                   4.0                     0.0
# 53204         NaN                   1.0                     0.0
# 53316         NaN                   0.0                     0.0
# 53408         NaN                   0.0                     0.0
# 53425         NaN                   7.0                     0.0
# 53453         NaN                   0.0                     1.0
# 53521         NaN                   0.0                     0.0
# 53534         NaN                   0.0                     0.0
# 53591         NaN                   1.0                     0.0
# 53612         NaN                   0.0                     0.0
# 53686         NaN                   0.0                     0.0
# 53713         NaN                   0.0                     0.0
# 53731         NaN                   0.0                     0.0
#
#        Total.Minor.Injuries  Total.Uninjured Weather.Condition  \
# 51768                   0.0              NaN               IMC
# 51955                   0.0              NaN               VMC
# 51987                   0.0              2.0               IMC
# 52013                   0.0              1.0               VMC
# 52361                   1.0              NaN               VMC
# 52687                   0.0              2.0               VMC
# 52708                   0.0              2.0               VMC
# 52932                   0.0              1.0               VMC
# 52974                   0.0              1.0               VMC
# 53002                   0.0              1.0               VMC
# 53036                   0.0              1.0               VMC
# 53039                   0.0              1.0               VMC
# 53040                   0.0              2.0               VMC
# 53088                   1.0              NaN               VMC
# 53089                   2.0              NaN               VMC
# 53096                   0.0              3.0               VMC
# 53185                   0.0              2.0               VMC
# 53190                   0.0              NaN               VMC
# 53204                   0.0              NaN               VMC
# 53316                   0.0              1.0               VMC
# 53408                   0.0              1.0               VMC
# 53425                   0.0              NaN               VMC
# 53453                   0.0              1.0               VMC
# 53521                   0.0              1.0               VMC
# 53534                   0.0              2.0               VMC
# 53591                   0.0              NaN               VMC
# 53612                   0.0              2.0               VMC
# 53686                   0.0              1.0               VMC
# 53713                   0.0              1.0               VMC
# 53731                   0.0              3.0               VMC
#
#       Broad.phase.of.flight   Report.Status Publication.Date  Total.Injuries
# 51768              Approach  Probable Cause       24-09-2014             4.0
# 51955              Approach  Probable Cause       05-06-2013             1.0
# 51987              Approach  Probable Cause       02-02-2009             0.0
# 52013               Landing  Probable Cause       01-02-2016             0.0
# 52361             Go-around  Probable Cause       11-02-2015             2.0
# 52687               Takeoff  Probable Cause       21-06-2011             0.0
# 52708               Landing  Probable Cause       02-07-2009             0.0
# 52932               Landing  Probable Cause       09-09-2002             0.0
# 52974               Landing  Probable Cause       13-05-2003             0.0
# 53002               Landing  Probable Cause       30-12-2003             0.0
# 53036               Landing  Probable Cause       04-11-2002             0.0
# 53039               Takeoff  Probable Cause       13-05-2003             0.0
# 53040               Takeoff  Probable Cause       13-05-2003             0.0
# 53088           Maneuvering  Probable Cause       06-12-2002             1.0
# 53089               Landing  Probable Cause       25-11-2003             2.0
# 53096               Landing  Probable Cause       13-05-2003             0.0
# 53185               Landing  Probable Cause       18-05-2010             0.0
# 53190               Takeoff  Probable Cause       16-12-2009             4.0
# 53204           Maneuvering  Probable Cause       05-05-2011             1.0
# 53316                Cruise  Probable Cause       20-09-2002             0.0
# 53408               Takeoff  Probable Cause       06-12-2002             0.0
# 53425               Takeoff  Probable Cause       21-04-2016             7.0
# 53453                  Taxi  Probable Cause       25-11-2003             1.0
# 53521               Landing  Probable Cause       13-05-2003             0.0
# 53534               Landing  Probable Cause       16-01-2003             0.0
# 53591               Takeoff  Probable Cause       13-05-2003             1.0
# 53612               Landing  Probable Cause       25-11-2003             0.0
# 53686               Landing  Probable Cause       01-04-2003             0.0
# 53713                  Taxi  Probable Cause       29-04-2003             0.0
# 53731               Takeoff  Probable Cause       25-02-2003             0.0

# %%
sum(new_df['Model'].isna())
# Out:
# 1

# %%
new_df = new_df.dropna(subset=['Model'])

# %%
##Karina complete this cell 
new_df = new_df.drop('Injury.Severity', axis =1, inplace = True)

# %%
## Karina: make a visual (bar graph?) on # of engines vs # of accidents

# %%
## Ermiyas: make a visual type of engine vs # of accidents

# %%
## Sangwon: make a visual for broad phase of flights vs # of accidents

# %%
## Ermiyas: use groupby for make/model and # of accidents using 'Total.Injuries' and value sort

# %%
## Sangwon: use groupby for make/model based on aircraft damage category
